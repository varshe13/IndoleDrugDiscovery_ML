# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import embeddingMethods.embedding_3d as e3
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdEHTTools
from rdkit.Chem import PeriodicTable as PeriodicTable
import pickle


import h5py
from scipy.spatial import ConvexHull
from tqdm import tqdm as tq


import importlib
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/jovyan/data/april_2024_data/drug_discovery_data/active_programs_database/programs

# %% [markdown]
# ## Defining Directories

# %%
#Defining Directories
Activedatabase_Dir = r'../active_database/Database_v4_3.xlsx'
#Activedatabase_Dir = r'../archive_databases/Database_v4_2.xlsx'

# %%
Indole_dataset = e3.dataset(Activedatabase_Dir)
# Out:
# Experimental Values
# 89it [00:00, 2363.42it/s]
# Litrature Indole (Benz) Values
# 142it [00:00, 1942.34it/s]
# Litrature Quinilones
# 14it [00:00, 2178.13it/s]

# %%
Indole_dataset.generate_embedded_conformers(confs = 10)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 245/245 [01:15<00:00,  3.23it/s]

# %%
Indole_dataset.generate_voxel_embedding(                         
                         batch_size=10,
                         out_dir = r'../DataSetOutputs/indole_embedding_101025/indole_embedding_101025.h5',
                         H_atom_diameter = 2,
                         min_max_norm = True,
                         check_shape = True,
                         return_channels=True,
                         verbose = True)

'''
Note that batching, batches embeddings by molecule not conformer
'''
# Out:
# Calculating Scaling Factor. . .
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 245/245 [00:00<00:00, 2062.28it/s]
# Scaling factor: 25.60787555102541
# Dimension size: 83
# Largest mol index: 131
# 1it [00:16, 16.29s/it]

# %% [markdown]
# ## Out DataFrame Generation

# %%
out_df = Indole_dataset.generate_out_df()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 245/245 [00:00<00:00, 3856.77it/s]

# %%
out_df
# Out:
#       Molecule ID  Conformer ID  GP Activity  GN Activity Dataset Source
# 0               0             0          1.0          1.0           None
# 1               0             1          1.0          1.0           None
# 2               0             2          1.0          1.0           None
# 3               0             3          1.0          1.0           None
# 4               0             4          1.0          1.0           None
# ...           ...           ...          ...          ...            ...
# 2445          244             5          1.0          1.0           None
# 2446          244             6          1.0          1.0           None
# 2447          244             7          1.0          1.0           None
# 2448          244             8          1.0          1.0           None
# 2449          244             9          1.0          1.0           None
#
# [2450 rows x 5 columns]

# %%
out_df.to_csv('../DataSetOutputs/indole_embedding_101025/indole_activities_101025.csv', index=False)

# %% [markdown]
# ## Data Visualization

# %%
# %matplotlib widget
Indole_dataset.compounds[0].vis_embedding(channel_idx = 0, conf_id = 0, style = 'mass')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 571787/571787 [00:00<00:00, 5308772.29it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
Indole_dataset.compounds[0].vis_embedding(channel_idx = 1, conf_id = 0, style = 'charge')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 2 Indole_dataset.compounds[0].vis_embedding(channel_idx = 1, conf_id = 0, style = 'charge')
#
# File ~/data/programs/embeddingMethods/embedding_3d.py:415, in molecule.vis_embedding(self, channel_idx, conf_id, style)
#     414 def vis_embedding(self, channel_idx, conf_id, style):
# --> 415     vis_channel(self.channel_embedding[conf_id][channel_idx], style)
#
# File ~/data/programs/embeddingMethods/embedding_3d.py:227, in vis_channel(channel, channel_ident)
#     224     #cmap = mpl.cm.seismic
#     225     norm = mpl.colors.Normalize(vmin=np.min(channel), vmax=np.max(channel))
# --> 227     fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cm.seismic),
#     228          cax=ax, orientation='vertical', label='Some Units')
#     230     '''
# ...
